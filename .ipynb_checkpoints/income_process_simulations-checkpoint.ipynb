# %% [markdown]
# ## Income Discretization Simulations
#
# This notebook simulates an AR(1) process and compares it to its discretized counterpart using the Rowenhorst and Tauchen method

# %%
using Distributions, QuantEcon, LinearAlgebra, Plots

# slight difference between this function and rowenhorst function in rowenhorst_tauchen.jl: this function does
# not normalize the ygrid

function rowenhorst(mean, uncond_sd, rho, num_states)
    """
    Rowenhort's method to approximate AR(1) process with Markov chain 
    
    #### Fields
    
    - 'mean': unconditional mean of income process
    - 'uncond_sd': unconditional standard deviation
    - 'rho': autocorrelation coefficient
    - 'num_states': number of states we want discretized
    
    #### Returns
    
    - 'transition_matrix': num_states x num_states array where
    transition_matrx[i,j] is prob. of going from i to j
    - 'ygrid': vector of income state space of length num_states
    
    """
    
    # construct grids
    step_r = uncond_sd*sqrt(num_states-1)
    ygrid = -1:2/(num_states-1):1
    ygrid = mean .+ step_r*ygrid
    
    # initialize transition probabilities 
    p = (rho+1)/2
    q = p
    
    transition_matrix = [p 1-p; 1-q q]
    
    # rowenhort's method
    for i = 2:num_states-1
        a1 = [transition_matrix zeros(i, 1); zeros(1, i+1)] 
        a2 = [zeros(i,1) transition_matrix; zeros(1, i+1)]
        a3 = [zeros(1, i+1); transition_matrix zeros(i,1)]
        a4 = [zeros(1, i+1); zeros(i,1) transition_matrix]
        
        transition_matrix = p*a1 + (1-p)*a2 + (1-q)*a3 + q*a4
        transition_matrix[2:i, :] = transition_matrix[2:i, :]/2
    end
    
    for i = 1:num_states
       transition_matrix[i,:] = transition_matrix[i,:]/sum(transition_matrix[i,:])
    end
    
    return transition_matrix, ygrid
end


function tauchen(mean, sd, rho, num_states; q=3)

    """
    Tauchen's method to approximate AR(1) process with Markov Chain
    
    ##### Fields
    
    - 'num_states': Number of points in markov process
    - 'sd' : Standard deviation of innovation
    - 'rho' : Autocorrelation coefficient
    - 'mean': Unconditional mean
    -  'q' : The number of standard deviations to each side of the process
    
    ##### Returns
    
    - 'transition_matrix': num_states x num_states array where
    transition_matrx[i,j] is prob. of going from i to j
    - 'ygrid': vector of income state space of length num_states
    
    """
    

      uncond_sd = sd/sqrt(1-rho^2)
      y = range(-q*uncond_sd, stop = q*uncond_sd, length = num_states)
      d = y[2]-y[1]

      Pi = zeros(num_states,num_states)

      for row = 1:num_states
        # end points
            Pi[row,1] = cdf(Normal(),(y[1] - rho*y[row] + d/2)/sd)
            Pi[row,num_states] = 1 - cdf(Normal(), (y[num_states] - rho*y[row] - d/2)/sd)

        # middle columns
            for col = 2:num_states-1
                Pi[row, col] = (cdf(Normal(),(y[col] - rho*y[row] + d/2) / sd) -
                               cdf(Normal(),(y[col] - rho*y[row] - d/2) / sd))
            end
      end

    yy = y .+ mean # center process around its mean

    Pi = Pi./sum(Pi, dims = 2) # renormalize

    return Pi, yy
end
# Out:
# tauchen (generic function with 1 method)

# %% [markdown]
# Let's simulate $y_{t} = 0.9 y_{t-1} + \varepsilon_t$ where $\varepsilon_t \sim N(0,1)$.

# %%
# Out:
# ([0.6768224022302549 0.32022490200344844 … 0.0 0.0; 0.05414682794950461 0.7002046099425492 … 1.854072451124012e-14 0.0; … ; 2.9553554080774857e-23 1.855817571455801e-14 … 0.7002046099425491 0.05414682794950455; 4.147655768732479e-33 2.8318649359989827e-22 … 0.3202249020034484 0.6768224022302549], -6.8824720161168536:2.294157338705618:6.8824720161168536)

# %%
function simulator(;mu = 0, rho = 0.9, num_states = 7, T = 10000)
    uncond_sd = 1/sqrt(1-0.9^2)

    transition_rowenhorst, ygrid_rowenhorst = rowenhorst(mu, uncond_sd, rho, num_states)
    transition_tauchen, ygrid_tauchen = tauchen(mu, 1, rho, num_states)
    
    mc_rowenhorst = MarkovChain(transition_rowenhorst, ygrid_rowenhorst)
    mc_tauchen = MarkovChain(transition_tauchen, ygrid_tauchen)

    sim_rowenhorst = simulate(mc_rowenhorst, T, init = 4)
    sim_tauchen = simulate(mc_tauchen, T, init = 4)
    
    shocks = rand(Normal(), 10000)
    y = zeros(T)
    
    for i = 2:T
        y[i] = rho*y[i-1] + shocks[i]
    end

    p1 = plot(sim_rowenhorst, label = "rowenhorst")
    p2 = plot(sim_tauchen, label = "tauchen")
    p3 = plot(y, label = "AR")
    
    p = plot(p1, p2, p3, layout = 3)
end

simulator()

# %% [markdown]
# Let's change $\rho$ to $0.999$. Rowenhorst does better for high persistence parameters.

# %%
simulator(rho = 0.999) # this also changes the unconditional variance
